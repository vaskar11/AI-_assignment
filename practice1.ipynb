# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv")
data
# Out:
#        842517  M  20.57  17.77   132.9    1326  0.08474  0.07864   0.0869  \
# 0    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 1    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 2    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# 3      843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780
# 4      844359  M  18.25  19.98  119.60  1040.0  0.09463  0.10900  0.11270
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 562    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 563    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 564    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 565    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 566     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#      0.07017  ...   24.99  23.41   158.8    1956   0.1238   0.1866  0.2416  \
# ...

# %%
titles= ['id' , 'diagnosis', 'radius_mean','texture_mean', 'perimeter_mean' , 'area_mean', 'smoothness_mean','compactness_mean' , 'concavity_mean', 'concave_points_mean' , 'symmetry_mean' , 'fractal_dimension_mean' ,'radius_se' , 'texture_se', 'perimeter_se', 'area_se' , 'smoothness_se' , 'compactness_se' , 'concavity_se','concave points_se' , 'symmetry_se', 'fractal_dimension_se' , 'radius_worst' , 'texture_worst' , 'perimeter_worst','area_worst' , 'smoothness_worst' , 'compactness_worst' , 'concavity_worst' , 'concave points_worst','symmetry_worst', 'fractal_dimension_worst']

# %%
data.columns=titles
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
# 566     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
 data.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv",index=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
# ...

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
# 566     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
print(id(data))
# Out:
# 1875421078288

# %%
data.shape
# Out:
# (567, 32)

# %% [markdown]
# # cancer and non cancer distrubutions

# %%
data.groupby('diagnosis').size()
# Out:
# diagnosis
# B    357
# M    210
# dtype: int64

# %% [markdown]
# ## vieww statistical data

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.670000e+02   567.000000    567.000000      567.000000   567.000000
# mean   3.047599e+07    14.109116     19.308042       91.842469   653.095062
# std    1.252289e+08     3.516074      4.291807       24.246060   351.099060
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692390e+05    11.695000     16.175000       75.100000   420.050000
# 50%    9.062900e+05    13.340000     18.870000       86.180000   546.400000
# 75%    8.836916e+06    15.765000     21.805000      103.750000   781.800000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       567.000000        567.000000      567.000000           567.000000
# mean          0.096342          0.104081        0.088430             0.048709
# ...

# %%
data.describe().T
# Out:
#                          count          mean           std          min  \
# id                       567.0  3.047599e+07  1.252289e+08  8670.000000
# radius_mean              567.0  1.410912e+01  3.516074e+00     6.981000
# texture_mean             567.0  1.930804e+01  4.291807e+00     9.710000
# perimeter_mean           567.0  9.184247e+01  2.424606e+01    43.790000
# area_mean                567.0  6.530951e+02  3.510991e+02   143.500000
# smoothness_mean          567.0  9.634190e-02  1.404996e-02     0.052630
# compactness_mean         567.0  1.040807e-01  5.239057e-02     0.019380
# concavity_mean           567.0  8.843000e-02  7.936421e-02     0.000000
# concave points_mean      567.0  4.870851e-02  3.864075e-02     0.000000
# symmetry_mean            567.0  1.810547e-01  2.734354e-02     0.106000
# fractal_dimension_mean   567.0  6.278035e-02  7.036396e-03     0.049960
# radius_se                567.0  4.037115e-01  2.762198e-01     0.111500
# ...

# %% [markdown]
# # EDA histogram

# %%
data.hist(figsize= (20,20))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'radius_mean'}>,
#         <Axes: title={'center': 'texture_mean'}>,
#         <Axes: title={'center': 'perimeter_mean'}>,
#         <Axes: title={'center': 'area_mean'}>,
#         <Axes: title={'center': 'smoothness_mean'}>],
#        [<Axes: title={'center': 'compactness_mean'}>,
#         <Axes: title={'center': 'concavity_mean'}>,
#         <Axes: title={'center': 'concave_points_mean'}>,
#         <Axes: title={'center': 'symmetry_mean'}>,
#         <Axes: title={'center': 'fractal_dimension_mean'}>,
#         <Axes: title={'center': 'radius_se'}>],
#        [<Axes: title={'center': 'texture_se'}>,
#         <Axes: title={'center': 'perimeter_se'}>,
#         <Axes: title={'center': 'area_se'}>,
#         <Axes: title={'center': 'smoothness_se'}>,
#         <Axes: title={'center': 'compactness_se'}>,
#         <Axes: title={'center': 'concavity_se'}>],
# ...

# %% [markdown]
# # Check skewness : value near 0 are less skewed as compared to away one and from -1 to 1 are normally skewed

# %%
skew_attribute= data.skew()
print(skew_attribute)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:494, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     492     return np.array(results)
# --> 494 return func(values, axis=axis, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:1240, in nanskew(values, axis, skipna, mask)
# ...

# %%
output_grp= data.groupby('diagnosis').size()
print(output_grp)
data.groupby('diagnosis').concave_points_mean.hist(alpha=1)
# Out:
# diagnosis
# B    357
# M    210
# dtype: int64
# diagnosis
# B    Axes(0.125,0.11;0.775x0.77)
# M    Axes(0.125,0.11;0.775x0.77)
# Name: concave_points_mean, dtype: object

# %%
data.boxplot(figsize=(20,20))
# Out:
# <Axes: >

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data,alpha=1,figsize=(10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='id', ylabel='id'>,
#         <Axes: xlabel='radius_mean', ylabel='id'>,
#         <Axes: xlabel='texture_mean', ylabel='id'>,
#         <Axes: xlabel='perimeter_mean', ylabel='id'>,
#         <Axes: xlabel='area_mean', ylabel='id'>,
#         <Axes: xlabel='smoothness_mean', ylabel='id'>,
#         <Axes: xlabel='compactness_mean', ylabel='id'>,
#         <Axes: xlabel='concavity_mean', ylabel='id'>,
#         <Axes: xlabel='concave_points_mean', ylabel='id'>,
#         <Axes: xlabel='symmetry_mean', ylabel='id'>,
#         <Axes: xlabel='fractal_dimension_mean', ylabel='id'>,
#         <Axes: xlabel='radius_se', ylabel='id'>,
#         <Axes: xlabel='texture_se', ylabel='id'>,
#         <Axes: xlabel='perimeter_se', ylabel='id'>,
#         <Axes: xlabel='area_se', ylabel='id'>,
#         <Axes: xlabel='smoothness_se', ylabel='id'>,
#         <Axes: xlabel='compactness_se', ylabel='id'>,
#         <Axes: xlabel='concavity_se', ylabel='id'>,
# ...

# %% [markdown]
# # heatmap plot

# %%
plt.figure(figsize=(12,12))
data = sns.heatmap(data.corr(),annot=True)# use of seaborn library heatmap
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.figure(figsize=(12,12))
# ----> 2 data = sns.heatmap(data.corr(),annot=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
data_new= data.copy(deep=True)
data_new[['id' , 'diagnosis', 'radius_mean','texture_mean', 'perimeter_mean' , 'area_mean', 'smoothness_mean','compactness_mean' , 'concavity_mean', 'concave_points_mean' , 'symmetry_mean' , 'fractal_dimension_mean' ,'radius_se' , 'texture_se', 'perimeter_se', 'area_se' , 'smoothness_se' , 'compactness_se' , 'concavity_se','concave points_se' , 'symmetry_se', 'fractal_dimension_se' , 'radius_worst' , 'texture_worst' , 'perimeter_worst','area_worst' , 'smoothness_worst' , 'compactness_worst' , 'concavity_worst' , 'concave points_worst','symmetry_worst', 'fractal_dimension_worst']]=data_new[['id' , 'diagnosis', 'radius_mean','texture_mean', 'perimeter_mean' , 'area_mean', 'smoothness_mean','compactness_mean' , 'concavity_mean', 'concave_points_mean' , 'symmetry_mean' , 'fractal_dimension_mean' ,'radius_se' , 'texture_se', 'perimeter_se', 'area_se' , 'smoothness_se' , 'compactness_se' , 'concavity_se','concave points_se' , 'symmetry_se', 'fractal_dimension_se' , 'radius_worst' , 'texture_worst' , 'perimeter_worst','area_worst' , 'smoothness_worst' , 'compactness_worst' , 'concavity_worst' , 'concave points_worst','symmetry_worst', 'fractal_dimension_worst']].replace(0,np.NaN)

# %%
print(data_new.isnull().sum())
# Out:
# id                          0
# diagnosis                   0
# radius_mean                 0
# texture_mean                0
# perimeter_mean              0
# area_mean                   0
# smoothness_mean             0
# compactness_mean            0
# concavity_mean             13
# concave_points_mean        13
# symmetry_mean               0
# fractal_dimension_mean      0
# radius_se                   0
# texture_se                  0
# perimeter_se                0
# area_se                     0
# smoothness_se               0
# compactness_se              0
# concavity_se               13
# concave points_se          13
# symmetry_se                 0
# fractal_dimension_se        0
# radius_worst                0
# texture_worst               0
# perimeter_worst             0
# area_worst                  0
# smoothness_worst            0
# compactness_worst           0
# concavity_worst            13
# concave points_worst       13
# symmetry_worst              0
# ...

# %%
print(data_new.head(40))
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   84300903         M       19.690         21.25          130.00     1203.0
# 1   84348301         M       11.420         20.38           77.58      386.1
# 2   84358402         M       20.290         14.34          135.10     1297.0
# 3     843786         M       12.450         15.70           82.57      477.1
# 4     844359         M       18.250         19.98          119.60     1040.0
# 5   84458202         M       13.710         20.83           90.20      577.9
# 6     844981         M       13.000         21.82           87.50      519.8
# 7   84501001         M       12.460         24.04           83.97      475.9
# 8     845636         M       16.020         23.24          102.70      797.8
# 9   84610002         M       15.780         17.89          103.60      781.0
# 10    846226         M       19.170         24.80          132.40     1123.0
# ...

# %%
data_new.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 562  926424         M        21.56         22.39          142.00     1479.0
# 563  926682         M        20.13         28.25          131.20     1261.0
# 564  926954         M        16.60         28.08          108.30      858.1
# 565  927241         M        20.60         29.33          140.10     1265.0
# 566   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 562          0.11100           0.11590         0.24390              0.13890
# 563          0.09780           0.10340         0.14400              0.09791
# 564          0.08455           0.10230         0.09251              0.05302
# 565          0.11780           0.27700         0.35140              0.15200
# 566          0.05263           0.04362             NaN                  NaN
#
# ...

# %%
cln_data=data_new.dropna()
cln_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 561    926125         M        20.92         25.09          143.00     1347.0
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
data_new.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 562    False
# 563    False
# 564    False
# 565    False
# 566    False
# Length: 567, dtype: bool

# %%
data_new.fillna({'concavity_mean':data_new['concavity_mean'].median(),'concave_points_mean':data_new['concave_points_mean'].median(),'concavity_se':data_new['concavity_se'].median,'concave points_se':data_new['concave points_se'].mean(),'concavity_worst':data_new['concavity_worst'].median(),'concave points_worst':data_new['concave points_worst'].mean()})
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
# 566     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data_new
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
# 566     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data_new.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data_new.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
# ...

# %%
data_new.tail(40)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 527    918465         B       12.070         13.44           77.83      445.2
# 528     91858         B       11.750         17.56           75.89      422.9
# 529  91903901         B       11.670         20.02           75.21      416.2
# 530  91903902         B       13.680         16.33           87.76      575.5
# 531  91930402         M       20.470         20.67          134.70     1299.0
# 532    919537         B       10.960         17.62           70.79      365.6
# 533    919555         M       20.550         20.86          137.80     1308.0
# 534  91979701         M       14.270         22.55           93.77      629.8
# 535    919812         B       11.690         24.44           76.37      406.4
# 536    921092         B        7.729         25.49           47.98      178.8
# 537    921362         B        7.691         25.44           48.34      170.4
# ...

# %%
data_new.fillna({'concavity_mean':data_new['concavity_mean'].median(),'concave_points_mean':data_new['concave_points_mean'].median(),'concavity_se':data_new['concavity_se'].median,'concave points_se':data_new['concave points_se'].mean(),'concavity_worst':data_new['concavity_worst'].median(),'concave points_worst':data_new['concave points_worst'].mean()})
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    84300903         M        19.69         21.25          130.00     1203.0
# 1    84348301         M        11.42         20.38           77.58      386.1
# 2    84358402         M        20.29         14.34          135.10     1297.0
# 3      843786         M        12.45         15.70           82.57      477.1
# 4      844359         M        18.25         19.98          119.60     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 562    926424         M        21.56         22.39          142.00     1479.0
# 563    926682         M        20.13         28.25          131.20     1261.0
# 564    926954         M        16.60         28.08          108.30      858.1
# 565    927241         M        20.60         29.33          140.10     1265.0
# 566     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data_new.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_new.to_csv("C:\\Users\\Vaska\\Downloads\\python\\practicedata.csv")
#
# NameError: name 'data_new' is not defined
